# %% [markdown]
# # We rate Dogs Twitter account’s data analysis
#
# ![WeRateDogsProfilePic.PNG](attachment:WeRateDogsProfilePic.PNG)

# %% [markdown]
# ## Table of Contents
# <ul>
#     <li>
#         <a href = "#intro">Introduction</a>
#     </li>
#     <li><a href = "#gather">Data Gathering</a></li>
#     <li><a href = "#assess">Data Assess</a></li>
#     <li><a href = "#clean">Data Cleaning</a></li>
#     <li><a href = "#save">Data Saving</a></li>
#     <li><a href = "#visual">Data Visualization</a></li>
#     <li><a href = "#conclude">Conclusion</a></li>
# </ul>

# %% [markdown]
# <a id = 'intro'></a>
# ## Introduction
#
# This project aims to gather data from three different sources, which are
# •	A csv file, that will be downloaded from Udacity site
# •	A tsv file that is to be downloaded programmatically using request.
# •	A Twitter user data (we rate dogs) which was  gotten by interacting with twitter’s API using tweepy package on python.
# assess the datasets, clean them and create analysis about the tweets and the predicted dog’s breed.
#
# <a id = 'gather'></a>
# ## Data Gathering
# I gathered the csv file by simply clicking on the link on the Udacity site and downloading it directly to my local machine. For the second data source which is a tsv file, I downloaded that using the requests package on python. Then, additional data was gotten from the twitter account using python’s tweepy package.
#
#
# <a id = 'assess'></a>
# ## Data Assessing
# I then assess the data sets both visually and programmatically to detect both Quality and Tidiness issues.
#
#
# <a id = 'clean'></a>
# ## Data Cleaning
# After identifying the quality and tidiness issues with the datasets, i then clean, the datasets by fixing the issues detected and i tackled each of the issues using the __Define__, __Code__ and __Test__ process.
#
#
# <a id = 'visual'></a>
# ## Data Visualization
# The research questions asked above were answered through analysing and visualising the dataset. Below is the visuals answering each of the questions:
# __Question1:__What is the most common dog stage
#
# ![Dog_stage_visual.png](attachment:Dog_stage_visual.png)
# It can be seen from the chart above, that pupper is the most common dog stage, followed by doggo, then puppo and lastly floofer
#
# __Question2:__What is the most common rating over ten given by users
#
# The highest rating given by users is __12__
#
# __Question3:__What are the top ten common names of dog
#
# ![Dog_names_visual.png](attachment:Dog_names_visual.png)
# From above, it can be seen that most of the dogs in the dataset had badly inputed name or had no names at all,
# but apart from them, Lucy is the most common name, followed closely behind by Charlie, then Cooper and Oliver
#
#
# __Question4:__Which dog has the most favourite dog count
#
# The details of the dog with the highest favourite count is:
# - It has a rating of 13 over 10
# - It wasn't named correctly
# - Its dog stage is puppo
# - Its source is from iphone
# - Its a lakeland_terrier dog
#
#
# __Question5:__What is the most common source of data
#
# ![Data_sources_visuals.png](attachment:Data_sources_visuals.png)
#
#
# __Question6:__Top ten dog breeds in P1,P2,P3
#
# ![P1.png](attachment:P1.png)
#
# ![p2.png](attachment:p2.png)
#
# ![p3.png](attachment:p3.png)
#
# <a id = 'conclude'></a>
# ## Conclusion
# I was able to document 20 issues during the first iteration of data wrangling, because data wrangling is an iterative process.
# For this reason, the final file version was analysed and visualised. This file has 2355 observations and 23 features.
# It can be concluded that based on this dataset:
#     - The most common dog name is pupper
#     - The most common rating given by users is 12
#     - The most common name given to a dog is Lucy
#     - A lakeland_terrier dog has the most favorite count
#     - The most common source  of the data is Twitter for Iphone
#     - According to  P1,P2 and P3, Golden retriever is the most common dog breed
